# %% [markdown]
# # Data-sources exploration using `eo-learn`

# %% [markdown]
# This notebook shows some examples on how to retrieve EO and non-EO data using `eo-learn`.
#
# The steps are as follow:
#  * split area of interest into easy-to-process EOPatches
#  * add Sentinel-2 imaging data
#  * add Sentinel-1 imaging data

# %% [markdown]
# Add generic packages

# %%
# %matplotlib inline

import os
from pathlib import Path

from matplotlib import dates
from mpl_toolkits.axes_grid1 import make_axes_locatable
from shapely.geometry import Polygon, box, shape, mapping
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %% [markdown]
# Set path to data

# %%
data_dir = Path('..', 'data')
os.listdir(data_dir)
# Out:
# ['.ipynb_checkpoints',
#  'denmark.geojson',
#  'land_use_10class_reference_slovenia_partial.gpkg',
#  'statapi_kranj.geojson',
#  'svn_border.geojson']

# %% [markdown]
# `eo-learn` and `sentinelhub` imports

# %%
from eolearn.core import EOTask, EOPatch, FeatureType
from eolearn.io import SentinelHubInputTask, SentinelHubEvalscriptTask
from eolearn.geometry import VectorToRasterTask

# %%
from sentinelhub import BBoxSplitter, BBox, CRS, DataCollection

# %% [markdown]
# ## 1. Split country into smaller bounding boxes <a id='splitter'></a>

# %% [markdown]
# Load shapefile of Denmark

# %%
country_filename = data_dir / 'denmark.geojson'
country = gpd.read_file(country_filename)

country.plot()
country.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Set CRS to UTM

# %%
country_crs = CRS.UTM_32N
country = country.to_crs(country_crs.pyproj_crs())

country.plot()
country.crs
# Out:
# <Derived Projected CRS: EPSG:32632>
# Name: WGS 84 / UTM zone 32N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
# - bounds: (6.0, 0.0, 12.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 32N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Get size of country in pixels to decide number and size of bounding boxes

# %%
country_shape = country.geometry.values[-1]

width_pix = int((country_shape.bounds[2] - country_shape.bounds[0]) / 10)
height_pix = int((country_shape.bounds[3] - country_shape.bounds[1]) / 10)

print(f'Dimension of the area is {width_pix} x {height_pix} pixels')
# Out:
# Dimension of the area is 45105 x 35243 pixels

# %% [markdown]
# Split area into 45x35 boxes bounding

# %%
bbox_splitter = BBoxSplitter([country_shape], country_crs, (45, 35))

# %%
geometry = [bbox.geometry for bbox in bbox_splitter.get_bbox_list()]
bbox_list = bbox_splitter.get_bbox_list()
idxs_x = [info['index_x'] for info in bbox_splitter.get_info_list()]
idxs_y = [info['index_y'] for info in bbox_splitter.get_info_list()]

gdf = gpd.GeoDataFrame(
    {'index_x':idxs_x, 'index_y':idxs_y},
    geometry=[bbox.geometry for bbox in bbox_list],
    crs=bbox_list[0].crs.pyproj_crs()
)

gdf.head()
# Out:
#    index_x  index_y                                           geometry
# 0        0       10  POLYGON ((441745.630 6150469.905, 441745.630 6...
# 1        0       11  POLYGON ((441745.630 6160539.386, 441745.630 6...
# 2        0       12  POLYGON ((441745.630 6170608.866, 441745.630 6...
# 3        0       13  POLYGON ((441745.630 6180678.347, 441745.630 6...
# 4        0       14  POLYGON ((441745.630 6190747.828, 441745.630 6...

# %% [markdown]
# Plot results

# %%
# if bboxes have all same size, estimate offset
xl, yl, xu, yu = gdf.geometry[0].bounds
xoff, yoff = (xu - xl) / 3, (yu - yl) / 5

# figure
fig, ax = plt.subplots(figsize=(45,35))
gdf.plot(ax=ax, facecolor='w', edgecolor='r', alpha=0.5, linewidth=2)
country.plot(ax=ax, facecolor='w', edgecolor='b', alpha=0.5, linewidth=2.5)
ax.set_title('Denmark tiled in a 45 x 35 grid');

# add annotiation text
fontdict = {'family': 'monospace', 'weight': 'normal', 'size': 14}
for idx in gdf.index:
    eop_name = '{0}x{1}'.format(gdf.index_x[idx], gdf.index_y[idx])
    centroid, = list(gdf.geometry[idx].centroid.coords)
    ax.text(centroid[0] - xoff, centroid[1] + yoff, str(idx), fontdict=fontdict)
    ax.text(centroid[0] - xoff, centroid[1] - yoff, eop_name, fontdict=fontdict)

# %% [markdown]
# ## 2. Retrieve S2 L1C data <a id="sentinel-2"></a>

# %%
s2_rgb_task = SentinelHubInputTask(
    data_collection=DataCollection.SENTINEL2_L1C,
    bands=['B04', 'B03', 'B02'],
    bands_feature=(FeatureType.DATA, 'S2-RGB'),
    additional_data=[(FeatureType.MASK, 'dataMask')],
    resolution=(10, 10),
    maxcc=0.1
)

# %%
ndvi_evalscript = """
//VERSION=3

function setup() {
  return {
    input: ["B04", "B08"],
    output:[
      {
        id: "ndvi",
        bands: 1,
        sampleType: SampleType.FLOAT32
      },
    ]
  }
}

function evaluatePixel(sample) {
  let ndvi = index(sample.B08, sample.B04);
  return {
    ndvi: [ndvi],
  };
}
"""

s2_ndvi_task = SentinelHubEvalscriptTask(
    features=[(FeatureType.DATA, 'ndvi', 'NDVI')],
    evalscript=ndvi_evalscript,
    data_collection=DataCollection.SENTINEL2_L1C,
    resolution=(10, 10),
    maxcc=0.1
)

# %%
time_interval = ['2019-05-01','2019-09-01']
idx = 436
bbox = bbox_splitter.bbox_list[idx]

# %% [markdown]
# Download TRUE-COLOR

# %%
eopatch = s2_rgb_task.execute(bbox=bbox, time_interval=time_interval)

eopatch
# Out:
# ---------------------------------------------------------------------------
# CustomOAuth2Error                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 eopatch = s2_rgb_task.execute(bbox=bbox, time_interval=time_interval)
#       3 eopatch
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\eolearn\io\sentinelhub_process.py:102, in SentinelHubInputBaseTask.execute(self, eopatch, bbox, time_interval, geometry)
#     100 if time_interval:
#     101     time_interval = parse_time_interval(time_interval)
# --> 102     timestamp = self._get_timestamp(time_interval, eopatch.bbox)
#     103     timestamp = [time_point.replace(tzinfo=None) for time_point in timestamp]
#     104 elif self.data_collection.is_timeless:
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\eolearn\io\sentinelhub_process.py:518, in SentinelHubInputTask._get_timestamp(self, time_interval, bbox)
#     515 if self.single_scene:
#     516     return [time_interval[0]]
# --> 518 return get_available_timestamps(
#     519     bbox=bbox,
#     520     time_interval=time_interval,
#     521     timestamp_filter=self.timestamp_filter,
#     522     data_collection=self.data_collection,
#     523     maxcc=self.maxcc,
#     524     time_difference=self.time_difference,
#     525     config=self.config,
#     526 )
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\eolearn\io\sentinelhub_process.py:752, in get_available_timestamps(bbox, data_collection, time_interval, time_difference, timestamp_filter, maxcc, config)
#     747 catalog = SentinelHubCatalog(config=config)
#     748 search_iterator = catalog.search(
#     749     collection=data_collection, bbox=bbox, time=time_interval, filter=query_filter, fields=fields
#     750 )
# --> 752 all_timestamps = search_iterator.get_timestamps()
#     753 return timestamp_filter(all_timestamps, time_difference)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\api\catalog.py:255, in CatalogSearchIterator.get_timestamps(self)
#     250 def get_timestamps(self) -> List[dt.datetime]:
#     251     """Provides features timestamps
#     252
#     253     :return: A list of sensing times
#     254     """
# --> 255     return [parse_time(feature["properties"]["datetime"], force_datetime=True) for feature in self]
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\api\catalog.py:255, in <listcomp>(.0)
#     250 def get_timestamps(self) -> List[dt.datetime]:
#     251     """Provides features timestamps
#     252
#     253     :return: A list of sensing times
#     254     """
# --> 255     return [parse_time(feature["properties"]["datetime"], force_datetime=True) for feature in self]
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\base.py:274, in FeatureIterator.__next__(self)
#     269 """Method called to provide the next feature in iteration
#     270
#     271 :return: the next feature
#     272 """
#     273 while self.index >= len(self.features) and not self.finished:
# --> 274     new_features = self._fetch_features()
#     275     self.features.extend(new_features)
#     277 if self.index < len(self.features):
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\api\catalog.py:242, in CatalogSearchIterator._fetch_features(self)
#     239 """Collects more results from the service"""
#     240 payload = remove_undefined({**self.params, "next": self.next})
# --> 242 results = self.client.get_json_dict(self.url, post_values=payload, use_session=True)
#     244 self.next = results["context"].get("next")
#     245 new_features = results["features"]
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\client.py:249, in DownloadClient.get_json_dict(self, url, extract_key, *args, **kwargs)
#     241 def get_json_dict(self, url: str, *args: Any, extract_key: Optional[str] = None, **kwargs: Any) -> JsonDict:
#     242     """Download request as JSON data type, failing if the result is not a dictionary
#     243
#     244     For other parameters see `get_json` method.
#    (...)
#     247     :param extract_key: If provided, the field is automatically extracted, checked, and returned
#     248     """
# --> 249     response = self.get_json(url, *args, **kwargs)
#     251     if not isinstance(response, dict):
#     252         raise MissingDataInRequestException(
#     253             f"Response from {url} was expected to be a dictionary, but got {type(response)}."
#     254         )
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\client.py:239, in DownloadClient.get_json(self, url, post_values, headers, request_type, **kwargs)
#     228     json_headers = {"Content-Type": MimeType.JSON.get_string(), **json_headers}
#     230 request = DownloadRequest(
#     231     url=url,
#     232     headers=json_headers,
#    (...)
#     236     **kwargs,
#     237 )
# --> 239 return self._single_download_decoded(request)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\client.py:117, in DownloadClient._single_download_decoded(self, request)
#     115 def _single_download_decoded(self, request: DownloadRequest) -> Any:
#     116     """Downloads a response and decodes it into data. By decoding a single response"""
# --> 117     response = self._single_download(request)
#     118     return None if response is None else response.decode()
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\client.py:130, in DownloadClient._single_download(self, request)
#     128 no_local_data = self.redownload or response_path is None or not os.path.exists(response_path)
#     129 if no_local_data:
# --> 130     response = self._execute_download(request)
#     131 else:
#     132     if not request.return_data or response_path is None:
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\handlers.py:65, in retry_temporary_errors.<locals>.new_download_func(self, request)
#      63 for attempt_idx in range(download_attempts):
#      64     try:
# ---> 65         return download_func(self, request)
#      67     except requests.RequestException as exception:
#      68         attempts_left = download_attempts - (attempt_idx + 1)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\handlers.py:38, in fail_user_errors.<locals>.new_download_func(self, request)
#      35 @functools.wraps(download_func)
#      36 def new_download_func(self: Self, request: DownloadRequest) -> T:
#      37     try:
# ---> 38         return download_func(self, request)
#      39     except requests.HTTPError as exception:
#      40         if (
#      41             exception.response.status_code < requests.status_codes.codes.INTERNAL_SERVER_ERROR
#      42             and exception.response.status_code != requests.status_codes.codes.TOO_MANY_REQUESTS
#      43         ):
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:82, in SentinelHubDownloadClient._execute_download(self, request)
#      75 if sleep_time == 0:
#      76     LOGGER.debug(
#      77         "Sending %s request to %s. Hash of sent request is %s",
#      78         request.request_type.value,
#      79         request.url,
#      80         request.get_hashed_name(),
#      81     )
# ---> 82     response = self._do_download(request)
#      84     self._execute_thread_safe(self.rate_limit.update, response.headers)
#      86     if response.status_code == requests.status_codes.codes.TOO_MANY_REQUESTS:
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:115, in SentinelHubDownloadClient._do_download(self, request)
#     108 if request.url is None:
#     109     raise ValueError(f"Faulty request {request}, no URL specified.")
#     111 return requests.request(
#     112     request.request_type.value,
#     113     url=request.url,
#     114     json=request.post_values,
# --> 115     headers=self._prepare_headers(request),
#     116     timeout=self.config.download_timeout_seconds,
#     117 )
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:126, in SentinelHubDownloadClient._prepare_headers(self, request)
#     124 session_headers: JsonDict = {}
#     125 if request.use_session:
# --> 126     session_headers = self._execute_thread_safe(self._get_session_headers)
#     128 return {**SHConstants.HEADERS, **session_headers, **request.headers}
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:101, in SentinelHubDownloadClient._execute_thread_safe(self, thread_unsafe_function, *args, **kwargs)
#      99 """Executes a function inside a thread lock and handles potential errors"""
#     100 if self.lock is None:
# --> 101     return thread_unsafe_function(*args, **kwargs)
#     103 with self.lock:
#     104     return thread_unsafe_function(*args, **kwargs)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:136, in SentinelHubDownloadClient._get_session_headers(self)
#     130 def _get_session_headers(self) -> JsonDict:
#     131     """Provides up-to-date session headers
#     132
#     133     Note that calling session_headers property triggers update if session has expired therefore this has to be
#     134     called in a thread-safe way
#     135     """
# --> 136     return self.get_session().session_headers
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\sentinelhub_client.py:152, in SentinelHubDownloadClient.get_session(self)
#     150     session = SentinelHubDownloadClient._CACHED_SESSIONS[SentinelHubDownloadClient._UNIVERSAL_CACHE_KEY]
#     151 else:
# --> 152     session = SentinelHubSession(config=self.config)
#     153     SentinelHubDownloadClient._CACHED_SESSIONS[cache_key] = session
#     155 return session
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\session.py:75, in SentinelHubSession.__init__(self, config, refresh_before_expiry, _token)
#      68 if token_fetching_required and not (self.config.sh_client_id and self.config.sh_client_secret):
#      69     raise ValueError(
#      70         "Configuration parameters 'sh_client_id' and 'sh_client_secret' have to be set in order "
#      71         "to authenticate with Sentinel Hub service. Check "
#      72         "https://sentinelhub-py.readthedocs.io/en/latest/configure.html for more info."
#      73     )
# ---> 75 self._token = self._collect_new_token() if _token is None else _token
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\session.py:129, in SentinelHubSession._collect_new_token(self)
#     123 """Creates a download request and fetches a token from the service.
#     124
#     125 Note that the `DownloadRequest` object is created only because retry decorators of `_fetch_token` method
#     126 require it.
#     127 """
#     128 request = DownloadRequest(url=f"{self.config.sh_auth_base_url}/oauth/token")
# --> 129 return self._fetch_token(request)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\handlers.py:65, in retry_temporary_errors.<locals>.new_download_func(self, request)
#      63 for attempt_idx in range(download_attempts):
#      64     try:
# ---> 65         return download_func(self, request)
#      67     except requests.RequestException as exception:
#      68         attempts_left = download_attempts - (attempt_idx + 1)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\handlers.py:38, in fail_user_errors.<locals>.new_download_func(self, request)
#      35 @functools.wraps(download_func)
#      36 def new_download_func(self: Self, request: DownloadRequest) -> T:
#      37     try:
# ---> 38         return download_func(self, request)
#      39     except requests.HTTPError as exception:
#      40         if (
#      41             exception.response.status_code < requests.status_codes.codes.INTERNAL_SERVER_ERROR
#      42             and exception.response.status_code != requests.status_codes.codes.TOO_MANY_REQUESTS
#      43         ):
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\sentinelhub\download\session.py:141, in SentinelHubSession._fetch_token(self, request)
#     138 with OAuth2Session(client=oauth_client) as oauth_session:
#     139     oauth_session.register_compliance_hook("access_token_response", self._compliance_hook)
# --> 141     return oauth_session.fetch_token(
#     142         token_url=request.url,
#     143         client_id=self.config.sh_client_id,
#     144         client_secret=self.config.sh_client_secret,
#     145         headers={**self.DEFAULT_HEADERS, **SHConstants.HEADERS},
#     146     )
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\requests_oauthlib\oauth2_session.py:366, in OAuth2Session.fetch_token(self, token_url, code, authorization_response, body, auth, username, password, method, force_querystring, timeout, headers, verify, proxies, include_client_id, client_secret, cert, **kwargs)
#     363     log.debug("Invoking hook %s.", hook)
#     364     r = hook(r)
# --> 366 self._client.parse_request_body_response(r.text, scope=self.scope)
#     367 self.token = self._client.token
#     368 log.debug("Obtained token %s.", self.token)
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\oauthlib\oauth2\rfc6749\clients\base.py:427, in Client.parse_request_body_response(self, body, scope, **kwargs)
#     379 """Parse the JSON response body.
#     380
#     381 If the access token request is valid and authorized, the
#    (...)
#     424 .. _`Section 7.1`: https://tools.ietf.org/html/rfc6749#section-7.1
#     425 """
#     426 scope = self.scope if scope is None else scope
# --> 427 self.token = parse_token_response(body, scope=scope)
#     428 self.populate_token_attributes(self.token)
#     429 return self.token
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\oauthlib\oauth2\rfc6749\parameters.py:441, in parse_token_response(body, scope)
#     438         params['expires_at'] = time.time() + int(params['expires_in'])
#     440 params = OAuth2Token(params, old_scope=scope)
# --> 441 validate_token_parameters(params)
#     442 return params
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\oauthlib\oauth2\rfc6749\parameters.py:448, in validate_token_parameters(params)
#     446 """Ensures token presence, token type, expiration and scope in params."""
#     447 if 'error' in params:
# --> 448     raise_from_error(params.get('error'), params)
#     450 if not 'access_token' in params:
#     451     raise MissingTokenError(description="Missing access token parameter.")
#
# File c:\Users\mracic\AppData\Local\Continuum\anaconda3\envs\eo\lib\site-packages\oauthlib\oauth2\rfc6749\errors.py:400, in raise_from_error(error, params)
#     398     if cls.error == error:
#     399         raise cls(**kwargs)
# --> 400 raise CustomOAuth2Error(error=error, **kwargs)
#
# CustomOAuth2Error: ({'status': 400, 'reason': 'Bad Request', 'message': 'Illegal client_id', 'code': 'OAUTH_ERROR'})

# %% [markdown]
# Download NDVI

# %%
eopatch = s2_ndvi_task.execute(eopatch)

eopatch

# %%
eopatch.timestamp

# %% [markdown]
# Plot RGB of time frames

# %%
time_idx = 0

rgb = eopatch.data['S2-RGB']

fig, ax = plt.subplots(figsize=(15, 15))
ax.imshow(rgb[time_idx] * 3.5);

# %% [markdown]
# Plot the median RGB values

# %%
fig, ax = plt.subplots(figsize=(15, 15))

ax.imshow(np.median(rgb, axis=0).squeeze() * 3.5);

# %% [markdown]
# Plot the median NDVI values

# %%
ndvi = eopatch.data['NDVI']
median_ndvi = np.median(ndvi, axis=0).squeeze()

fig, ax = plt.subplots(figsize=(15,15))
im = ax.imshow(median_ndvi, cmap=plt.cm.YlGn)

divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im, cax=cax, orientation='vertical');

# %% [markdown]
# Plot temporal NDVI of a given location

# %%
dates_num = dates.date2num(eopatch.timestamp)
dates_str = [timestamp.date().isoformat() for timestamp in eopatch.timestamp]

fig, ax = plt.subplots(figsize=(15, 15))
ax.plot(dates_num, ndvi[:, 100, 550, :].squeeze(), 'g')

ax.set_title('NDVI evolution')
ax.set_xticks(dates_num);
ax.set_xticklabels(dates_str, rotation=45, ha='right');
ax.set_ylabel('NDVI');

# %% [markdown]
# ## 4. Retrieve S1 data <a id="sentinel-1"></a>

# %%
s1_iw_des_task = SentinelHubInputTask(
    data_collection=DataCollection.SENTINEL1_IW_DES,
    bands=['VV'],
    bands_feature=(FeatureType.DATA, 'S1-IW-DES'),
    additional_data=[(FeatureType.MASK, 'dataMask')],
    resolution=(10, 10)
)

s1_iw_asc_task = SentinelHubInputTask(
    data_collection=DataCollection.SENTINEL1_IW_ASC,
    bands=['VV'],
    bands_feature=(FeatureType.DATA, 'S1-IW-ASC'),
    additional_data=[(FeatureType.MASK, 'dataMask')],
    resolution=(10, 10)
)

# %%
eopatch_s1_des = s1_iw_des_task.execute(bbox=bbox, time_interval=['2019-07-01','2019-08-01'])

eopatch_s1_des

# %% [markdown]
# [VV-polarised Timescan Composite](https://github.com/ESA-PhiLab/OpenSarToolkit/blob/master/README.md)

# %%
vv_data = eopatch_s1_des.data['S1-IW-DES']
vv_data[np.isnan(vv_data)] = 0

vv_des_r = np.percentile(vv_data, 80, axis=0)
vv_des_g = np.percentile(vv_data, 20, axis=0)
vv_des_b = np.std(vv_data, axis=0)

vv_rgb = np.concatenate((vv_des_r, vv_des_r, vv_des_b), axis=-1)

plt.figure(figsize=(15, 15))
plt.imshow(vv_rgb);

# %%
eopatch_s1_asc = s1_iw_asc_task.execute(bbox=bbox, time_interval=['2019-07-01','2019-08-01'])

eopatch_s1_asc

# %%
vv_data = eopatch_s1_asc.data['S1-IW-ASC']
vv_data[np.isnan(vv_data)] = 0

vv_des_r = np.percentile(vv_data, 80, axis=0)
vv_des_g = np.percentile(vv_data, 20, axis=0)
vv_des_b = np.std(vv_data, axis=0)

vv_rgb = np.concatenate((vv_des_r, vv_des_r, vv_des_b), axis=-1)

plt.figure(figsize=(15, 15))
plt.imshow(vv_rgb);

# %%
vv_data.shape

# %%
vv_data = eopatch_s1_asc.data['S1-IW-ASC']
vv_data[np.isnan(vv_data)] = 0

vv_des_r = vv_data[0]
vv_des_g = vv_data[2]
vv_des_b = vv_data[10]

vv_rgb = np.concatenate((vv_des_r, vv_des_r, vv_des_b), axis=-1)

plt.figure(figsize=(15, 15))
plt.imshow(vv_rgb);

# %% [markdown]
# Similarly, Sentinel-2 L2A data can be added, as well as Digital Elevation data
